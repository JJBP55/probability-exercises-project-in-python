# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO
import random
import numpy as np

def simulacion(iteraciones):
    i = 0                                               #contador
    for n in range(iteraciones):
        dado1 = random.randint(1, 6)
        dado2 = random.randint(1, 6)
        suma = dado1 + dado2                            #suma del resultado de los 2 dados
        if(suma > 7) or (suma % 2 == 0):                #si es mayor a 7 o es par
            i += 1
    return i / iteraciones                              #contador entre las iteraciones

print(f"La probabilidad de un 7 o par es: {np.round(simulacion(1000) * 100, 2)}%")
# Out:
# La probabilidad de un 7 o par es: 66.1%

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import numpy as np

ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
            
# TODO
iteraciones = 1000
exitos_caso1 = 0                                                #contador para "3 blancas y 2 rojas"
exitos_caso2 = 0                                                #contador para "Todas del mismo color"

for _ in range(iteraciones):
    extraccion_actual = []
    
    for _ in range(5):
        bola_elegida = np.random.randint(0, 59)
        color = ball_box[bola_elegida]                          #buscamos el color en el diccionario y lo guardamos
        extraccion_actual.append(color)
        
    blancas = extraccion_actual.count("White")                  #contamos cuántas bolas de cada color salieron en esta ronda de 5
    rojas = extraccion_actual.count("Red")
    verdes = extraccion_actual.count("Green")
    
    if blancas == 3 and rojas == 2:                             #verificamos si salieron 3 blancas y 2 rojas
        exitos_caso1 += 1
        
    if blancas == 5 or rojas == 5 or verdes == 5:               #verificamos si todas son del mismo color 
        exitos_caso2 += 1

probabilidad_1 = exitos_caso1 / iteraciones
probabilidad_2 = exitos_caso2 / iteraciones

print(f"1. Probabilidad estimada de sacar 3 blancas y 2 rojas: {np.round(probabilidad_1 * 100, 2)}%")
print(f"2. Probabilidad estimada de sacar todas del mismo color: {np.round(probabilidad_2 * 100, 2)}%")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# 1. Probabilidad estimada de sacar 3 blancas y 2 rojas: 0.8%
# 2. Probabilidad estimada de sacar todas del mismo color: 4.1%
